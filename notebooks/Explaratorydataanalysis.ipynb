# %%
import os , sys
sys.path.append(os.path.abspath('../scripts'))

# %%
import pandas as pd

# %% [markdown]
# # Exploratory Data Analysis for the Dataframe

# %%
import eda as eda

# %% [markdown]
# ### Loading the data

# %%
path_1 = '../data/fun-things-to-do-in-cairo.csv'
df_1 = eda.load_data(path_1)

# %%
df_1.head()
# Out:
#                     Name                     Type of Activity  \
# 0          Al Azhar Park                     Outdoor Activity
# 1   Aquarium Grotto Park                     Outdoor Activity
# 2            Family Park                     Outdoor Activity
# 3  Nile Cruise (Felucca)                     Outdoor Activity
# 4                  Zawya  Movie Screenings & Art Performances
#
#                                          Description  \
# 0  A large park with beautiful gardens and recrea...
# 1     A park featuring an aquarium and scenic views.
# 2    A family-friendly park with various activities.
# 3                     Sail the Nile River at sunset.
# 4  Art-house cinema screening alternative films a...
#
#                     Location          Opening Times
# 0                      Cairo                    N/A
# 1             Zamalek, Cairo                    N/A
# 2                  New Cairo                    N/A
# 3             Maadi, Zamalek                    N/A
# ...

# %% [markdown]
# ### Overview Of The Data Frame

# %%
eda.overview_of_the_data(df_1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              46 non-null     object
#  1   Type of Activity  46 non-null     object
#  2   Description       46 non-null     object
#  3   Location          46 non-null     object
#  4   Opening Times     45 non-null     object
# dtypes: object(5)
# memory usage: 1.9+ KB

# %% [markdown]
# ### Summary of the the catagorical columns

# %%
eda.summary_of_catagorical_columns(df_1)
# Out:
# Value counts for Name:
# Name
# Al Azhar Park                   1
# Aquarium Grotto Park            1
# Family Park                     1
# Nile Cruise (Felucca)           1
# Zawya                           1
# Magnolia Leaves of Art          1
# Wekalet El-Ghouri               1
# Grip n Climb                    1
# Ski Egypt                       1
# Autovrooom Cairo                1
# Gravity Code                    1
# Verticality Zorbing Park        1
# AirZone Egypt                   1
# Aerodium Egypt                  1
# Funtopia Cairo                  1
# Adrenalin Park                  1
# Sky Zone Egypt                  1
# The Battlefield                 1
# Bounce Inc                      1
# C.O.D.E. Paintball Egypt        1
# Nile Kayak Club                 1
# Sherlocked Egypt                1
# Nightmare Escape Egypt          1
# Escape Room Egypt               1
# Mind Maze                       1
# Escapology                      1
# ...

# %% [markdown]
# ### visualization

# %%
eda.visualization(df_1)

# %% [markdown]
# ### eord cloud for the description column

# %%
eda.word_cloud_for_description(df_1)

# %%
eda.correlation_and_relationships(df_1)
# Out:
# Location                             1 Palestine St., El Bandar Mall – Maadi  \
# Type of Activity
# Arcade                                                                     0
# Bowling                                                                    1
# Cooking Class                                                              0
# Cultural Show                                                              0
# Escape Room                                                                0
# Horror House                                                               0
# Karaoke                                                                    0
# Maze Experience                                                            0
# Movie Screenings & Art Performances                                        0
# Outdoor Activity                                                           0
# Stress Relief                                                              0
# ...
