# %%
from bs4 import BeautifulSoup
import requests

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
}
url = 'https://whynotegypt.com/blog/fun-things-to-do-in-cairo/'
page = requests.get(url , headers=headers)
soup = BeautifulSoup(page.text,'html')

# %%
title = soup.find('title').text
print(title)
# Out:
# 52 Fun Things to Do in Cairo & Where to Find Them | Why Not Egypt?

# %%
page
# Out:
# <Response [200]>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <link href="https://whynotegypt.com/xmlrpc.php" rel="pingback"/>
# <meta content="width=device-width,initial-scale=1,user-scalable=yes" name="viewport"/>
# <script type="application/javascript">var mkdfToursAjaxURL = "https://whynotegypt.com/wp-admin/admin-ajax.php"</script><meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v23.6 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>52 Fun Things to Do in Cairo &amp; Where to Find Them | Why Not Egypt?</title>
# <meta content="Are you looking for fun things to do in Cairo, besides sightseeing and eating? We have compiled a list of 52 fun activities to do in Cairo to suit everyone." name="description"/>
# <link href="https://whynotegypt.com/blog/fun-things-to-do-in-cairo/" rel="canonical">
# <meta content="en_US" property="og:locale"/>
# ...

# %%
# Set headers to mimic a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
}

url2 = 'https://whynotegypt.com/blog/fun-things-to-do-in-cairo/'
page_2 = requests.get(url2,headers=headers)
soup_2 = BeautifulSoup(page.text,'html.parser')

# %%
page_2
# Out:
# <Response [200]>

# %%
soup_2
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="always" name="referrer">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="https://www.facebook.com/edarabia" property="article:author"/>
# <meta content="https://www.edarabia.com/things-to-do-cairo-with-kids/" property="og:url"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.edarabia.com/xmlrpc.php" rel="pingback"/>
# <link href="https://www.edarabia.com/wp-content/themes/newed/assets/images/favicon.png" rel="icon" type="image/x-icon"/>
# <link href="https://www.edarabia.com/wp-content/themes/newed/assets/images/favicon.png" rel="shortcut icon" type="image/x-icon"/>
# <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
# ...

# %%
title = soup_2.find('title').text
print(title)
# Out:
# 19 Fun Things to Do in Cairo with Kids (2024)

# %%
soup_2.find('div',class_ = 'mkdf-post-text-main')

# %%
# Assuming you've already created soup_2 with BeautifulSoup
div_content = soup.find('div', class_='mkdf-post-text-main')

# Check if the div was found
if div_content:
    print(div_content.text)  # Prints only the text content
    # OR print(div_content) to print the entire HTML content of the div
else:
    print("The div with class 'mkdf-post-text-main' was not found.")
# Out:
# Egyptians could easily be nominated the foodie-st nation in the world, in fact, meeting-up in restaurants and cafes in Cairo is Cairenes’ or even most Egyptians’ preferred hangout, but when we are fed up with food, having tried all shisha flavors that came into existence, or ran out of topics to discuss, we start wandering around in circles, looking for fun things to do in Cairo that do not involve food. So what do Egyptians do for fun?
# Activities to Do in Cairo
# I am sure that you are wondering; besides Cairo tourist attractions, eating, or sitting in cafes, what to do in Cairo? Are there any adventurous things to do in Cairo, or cool activities? After doing some research, I have compiled a list of 52 activities in Cairo that suits almost everyone.
# Read this post, to find out what you can see and do while spending 3 days in Cairo.
# For the Love of Outdoor Activities in Cairo
# Spend a day at an Amusement Park
#
# Al Azhar Park in Cairo
# ...

# %%
import pandas as pd
import numpy as np



# Define lists to hold the scraped data
activity_types = []
descriptions = []
locations = []
show_times = []
prices = []

# Locate all the main sections (h3 tags) and their subsequent details
for section in soup.find_all('h3'):
    # Get the activity type from the h3 text
    activity_type = section.get_text(strip=True)
    
    # Initialize details for this section
    about = np.nan
    location = np.nan
    show_time = np.nan
    price = np.nan
    
    # Find the next siblings, where the details are located
    sibling = section.find_next_sibling()
    
    while sibling and sibling.name not in ['h3', 'h2']:
        # Check for different types of tags for various details
        if sibling.name == 'ul':
            for li in sibling.find_all('li'):
                if 'About:' in li.get_text():
                    about = li.get_text(strip=True).replace('About: ', '')
                elif 'Location:' in li.get_text():
                    location = li.get_text(strip=True).replace('Location: ', '')
                elif 'Show-times:' in li.get_text() or 'Opening times:' in li.get_text():
                    show_time = li.get_text(strip=True).replace('Show-times: ', '').replace('Opening times: ', '')
                elif 'Pricing:' in li.get_text():
                    price = li.get_text(strip=True).replace('Pricing: ', '')
        
        # Move to the next sibling element
        sibling = sibling.find_next_sibling()
    
    # Append the scraped details to the lists
    activity_types.append(activity_type)
    descriptions.append(about)
    locations.append(location)
    show_times.append(show_time)
    prices.append(price)

# Create a DataFrame to hold the scraped data
df = pd.DataFrame({
    'Activity_Type': activity_types,
    'Description': descriptions,
    'Location': locations,
    'Show_Time': show_times,
    'Price': prices
})

# Replace any empty string with NaN for consistency
df.replace('', np.nan, inplace=True)

# Save the DataFrame to a CSV file
df.to_csv('cairo_activities.csv', index=False)

print("Data has been scraped and saved to 'cairo_activities.csv'")
# Out:
# Data has been scraped and saved to 'cairo_activities.csv'

# %%
data = pd.read_csv('cairo_activities.csv')
data
# Out:
#                                         Activity_Type  \
# 0   52 Fun Things to Do in Cairo (That Don’t Invol...
# 1                           Activities to Do in Cairo
# 2         For the Love of Outdoor Activities in Cairo
# 3                 Movie Screenings & Art Performances
# 4      Random Stuff to Do in Cairo for Thrill-Seekers
# 5   Some More Fun Activities in Cairo for the Acti...
# 6   Master the Art of Escape at One of Cairo’s Esc...
# 7   Get Your Adrenalin Pumping By Entering One of ...
# 8   Spend Endless Hours of Fun Playing Arcades in ...
# 9                                    Bowling in Cairo
# 10  Virtual Reality – A Three Dimensional Gaming E...
# 11                                Release Your Stress
# 12            Cooking – well this one involves food 🙂
#
#                                           Description  \
# 0                                                 NaN
# 1                                                 NaN
# ...

# %%
soup.find('div',class_='mkdf-post-text-main')
# Out:
# <div class="mkdf-post-text-main">
# <p><a href="https://www.whynotegypt.com/funny-facts-about-egyptians/" rel="noopener noreferrer" target="_blank">Egyptians</a> could easily be nominated the foodie-st nation in the world, in fact, meeting-up in restaurants and cafes in Cairo is Cairenes’ or even most Egyptians’ preferred hangout, but when we are fed up with food, having tried all shisha flavors that came into existence, or ran out of topics to discuss, we start wandering around in circles, looking for <strong>fun things to do in Cairo that do not involve food</strong>. So what do Egyptians do for fun?</p>
# <h3>Activities to Do in Cairo</h3>
# ...

# %%
class_name_four_soup_2 = "mkdf-post-text-main"
<div class="mkdf-post-text-main">

# %%
activity_types = []
descriptions = []
locations = []
show_times = []
prices = []

# %%
df_cairo = pd.read_csv('../data/fun-things-to-do-in-cairo.csv')
df_cairo.head()
# Out:
#                     Name                     Type of Activity  \
# 0          Al Azhar Park                     Outdoor Activity
# 1   Aquarium Grotto Park                     Outdoor Activity
# 2            Family Park                     Outdoor Activity
# 3  Nile Cruise (Felucca)                     Outdoor Activity
# 4                  Zawya  Movie Screenings & Art Performances
#
#                                          Description  \
# 0  A large park with beautiful gardens and recrea...
# 1     A park featuring an aquarium and scenic views.
# 2    A family-friendly park with various activities.
# 3                     Sail the Nile River at sunset.
# 4  Art-house cinema screening alternative films a...
#
#                     Location          Opening Times
# 0                      Cairo                    N/A
# 1             Zamalek, Cairo                    N/A
# 2                  New Cairo                    N/A
# 3             Maadi, Zamalek                    N/A
# ...

# %%
df_cairo.shape
# Out:
# (46, 5)

# %%
df_cairo
# Out:
#                             Name                     Type of Activity  \
# 0                  Al Azhar Park                     Outdoor Activity
# 1           Aquarium Grotto Park                     Outdoor Activity
# 2                    Family Park                     Outdoor Activity
# 3          Nile Cruise (Felucca)                     Outdoor Activity
# 4                          Zawya  Movie Screenings & Art Performances
# 5         Magnolia Leaves of Art  Movie Screenings & Art Performances
# 6              Wekalet El-Ghouri                        Cultural Show
# 7                   Grip n Climb              Thrill-Seeking Activity
# 8                      Ski Egypt              Thrill-Seeking Activity
# 9               Autovrooom Cairo              Thrill-Seeking Activity
# 10                  Gravity Code              Thrill-Seeking Activity
# 11      Verticality Zorbing Park              Thrill-Seeking Activity
# ...

# %%
df_things_to_do_with_kids = pd.read_csv('../data/things-to-do-cairo-with-kids.csv')
df_things_to_do_with_kids.head()
# Out:
#                                        Name  Type of Activity  \
# 0  Ride the Camels and Revisit the Pyramids  Outdoor Activity
# 1           Interact with Animals at Kidzoo  Outdoor Activity
# 2        Discover Animal Planet at Giza Zoo  Outdoor Activity
# 3  Appreciate Art in Nature at Fagnoon Farm  Outdoor Activity
# 4            Empower Kids at Kidzania Cairo   Indoor Activity
#
#                                          Description  \
# 0  Visit the Great Pyramid of Giza, ride camels, ...
# 1  A small zoo where kids can interact with anima...
# 2  Explore a large collection of animals and visi...
# 3  Engage in art activities and enjoy farm life e...
# 4  A miniature city where kids can role-play vari...
#
#                      Location                             Opening Times
# 0                 Giza, Cairo                                       N/A
# 1           Obour City, Cairo                                       N/A
# ...

# %%
df_things_to_do_with_kids
# Out:
#                                                  Name   Type of Activity  \
# 0            Ride the Camels and Revisit the Pyramids   Outdoor Activity
# 1                     Interact with Animals at Kidzoo   Outdoor Activity
# 2                  Discover Animal Planet at Giza Zoo   Outdoor Activity
# 3            Appreciate Art in Nature at Fagnoon Farm   Outdoor Activity
# 4                      Empower Kids at Kidzania Cairo    Indoor Activity
# 5             Stay for the Weekend at Blue Lotus Farm   Outdoor Activity
# 6                Go on a Nature Trip at Al Sorat Farm   Outdoor Activity
# 7               Watch a Performance at Sitara Theater  Cultural Activity
# 8                              Explore Parks in Cairo   Outdoor Activity
# 9                        Have Endless Fun at ClubLiko    Indoor Activity
# 10        Buy Great Souvenir Finds at Khan el-Khalili           Shopping
# 11                      Play and Socialize at Kiddles    Indoor Activity
# ...
